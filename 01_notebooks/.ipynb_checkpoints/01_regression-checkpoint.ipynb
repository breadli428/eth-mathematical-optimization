# %% [markdown]
# ## Exercise: Linear regression minimizing $\ell_1$-error
#
# <font color='blue'><b>Goal:</b></font>
# Solve linear regression with an $\ell_1$-error function using a linear program.
#
# <font color='blue'><b>Additional resources:</b></font>
# For an introduction on regression, see https://stat.ethz.ch/education/semesters/ss2016/regression/Regression.pdf.
#
# ---
#
# A researcher would like to know if a child's height $H$ (in cm) can be predicted by their age $A$ (in years).
# In other words, she would like to know if there is any relationship between $A$ and $H$.
# She begins by observing the age and height of fifteen children.
# Her data is stored below (the first child was age 1 with height 73.2, the second child was age 1 with height 73.3, etc.).

# %%
# Observed ages in years
obs_age = [1,1,2,2,3,4,4,5,6,7,7,8,9,9,10]

# Observed heights in cm
obs_ht = [73.2,73.3,75.1,77.4,80.1,85.7,84.0,89.1,100.2,105.3,112.2,115.0,125.1,135.2,150.7]

# %% [markdown]
# We can visualize this data using the `matplotlib` library in Python.
# The `plt.scatter` plots the individual data points.
#
# We can also draw different lines through the data to visualize a linear relationship.
#
# <font color='red'><b>Note:</b></font> There are many ways to plot a line in `matplotlib`.
# One method involves using the `numpy` Python package.
#
# Run the following code to plot the data and to draw the lines $H = 7A+65$ and $H = 5.75A+70$.

# %%
# Import Python's plotting tools (matplotlib) and math tools (numpy)
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Plot the points
plt.scatter(obs_age,obs_ht)

# Draw the line H = 7A+65
A = np.linspace(1,10,100)
H = 7*A+65
plt.plot(A,H, color = 'red')

# Draw the line H = 5.75A+70
H = 5.75*A+70
plt.plot(A,H, color = 'green')


plt.xlabel("Age (in years)")
plt.ylabel("Height (in cm)")
plt.show()

# %% [markdown]
# Both lines $H = 7A + 65$ and $H = 5.75A + 70$ seem to capture some of the correlation between `obs_ages` and `obs_ht`.
# However, which line is the better choice?
# Regression measures this with a loss function.
#
# Given values $\alpha, \beta \in \mathbb{R}$, we say that the $\ell_1$-error of the line $H = \beta A + \alpha$ is equal to
# $$
# \displaystyle \sum_{i=1}^{15} |\text{obs_ht}_{~i} - (\beta \times \text{obs_age}_{~i} + \alpha)|.
# $$
#
# The line $H = 7A + 65$ has an $\ell_1$ error of $90.19$, and the line $H = 5.75A + 70$ has an $\ell_1$ error of $100.80$.
#
# <font color="blue"><b>Your first task:</b></font>
# Write an LP that finds parameters $\alpha$ and $\beta$ so that the line $H = \beta A + \alpha$ minimizes the $\ell_1$-error.<br>
# Implement this LP and solve it. Also, plot the optimal line $H$ that you found together with the data.

# %%
# Solve the L-1 linear regression problem here...

from pulp import *


Re_LP = LpProblem("regression", LpMinimize)
beta = LpVariable("slope")
alpha = LpVariable("intercept")
z = [LpVariable(f"abs{i}", lowBound=0) for i in range(15)]

Re_LP += lpSum(z)

for i in range(15):
    Re_LP += z[i] >= obs_ht[i] - (beta * obs_age[i] + alpha)
    Re_LP += z[i] >= -obs_ht[i] + (beta * obs_age[i] + alpha)

print(Re_LP)

Re_LP.solve()

print(f'The optimal beta is {beta.value()}')
print(f'The optimal alpha is {alpha.value()}')


# Plot the points
plt.scatter(obs_age,obs_ht)

A = np.linspace(1,10,100)
H = beta.value() * A + alpha.value()
plt.plot(A, H, color='green')


plt.xlabel("Age (in years)")
plt.ylabel("Height (in cm)")
plt.show()
# Out:
# regression:
# MINIMIZE
# 1*abs0 + 1*abs1 + 1*abs10 + 1*abs11 + 1*abs12 + 1*abs13 + 1*abs14 + 1*abs2 + 1*abs3 + 1*abs4 + 1*abs5 + 1*abs6 + 1*abs7 + 1*abs8 + 1*abs9 + 0
# SUBJECT TO
# _C1: abs0 + intercept + slope >= 73.2
#
# _C2: abs0 - intercept - slope >= -73.2
#
# _C3: abs1 + intercept + slope >= 73.3
#
# _C4: abs1 - intercept - slope >= -73.3
#
# _C5: abs2 + intercept + 2 slope >= 75.1
#
# _C6: abs2 - intercept - 2 slope >= -75.1
#
# _C7: abs3 + intercept + 2 slope >= 77.4
#
# _C8: abs3 - intercept - 2 slope >= -77.4
#
# _C9: abs4 + intercept + 3 slope >= 80.1
#
# _C10: abs4 - intercept - 3 slope >= -80.1
#
# _C11: abs5 + intercept + 4 slope >= 85.7
#
# _C12: abs5 - intercept - 4 slope >= -85.7
#
# _C13: abs6 + intercept + 4 slope >= 84
#
# _C14: abs6 - intercept - 4 slope >= -84
#
# _C15: abs7 + intercept + 5 slope >= 89.1
#
# _C16: abs7 - intercept - 5 slope >= -89.1
#
# _C17: abs8 + intercept + 6 slope >= 100.2
#
# _C18: abs8 - intercept - 6 slope >= -100.2
#
# _C19: abs9 + intercept + 7 slope >= 105.3
#
# _C20: abs9 - intercept - 7 slope >= -105.3
#
# _C21: abs10 + intercept + 7 slope >= 112.2
#
# _C22: abs10 - intercept - 7 slope >= -112.2
#
# _C23: abs11 + intercept + 8 slope >= 115
#
# _C24: abs11 - intercept - 8 slope >= -115
#
# _C25: abs12 + intercept + 9 slope >= 125.1
#
# _C26: abs12 - intercept - 9 slope >= -125.1
#
# _C27: abs13 + intercept + 9 slope >= 135.2
#
# _C28: abs13 - intercept - 9 slope >= -135.2
#
# _C29: abs14 + intercept + 10 slope >= 150.7
#
# _C30: abs14 - intercept - 10 slope >= -150.7
#
# VARIABLES
# abs0 Continuous
# abs1 Continuous
# abs10 Continuous
# abs11 Continuous
# abs12 Continuous
# abs13 Continuous
# abs14 Continuous
# abs2 Continuous
# abs3 Continuous
# abs4 Continuous
# abs5 Continuous
# abs6 Continuous
# abs7 Continuous
# abs8 Continuous
# abs9 Continuous
# intercept free Continuous
# slope free Continuous
#
# The optimal beta is 7.1428571
# The optimal alpha is 60.814286

# %% [markdown]
# Perhaps the relationship between age and height is not linear.
# In fact the data in the previous plot seems to suggest that the relationship is more quadratic.
# We can also use linear programming to solve this quadratic regression problem!
#
# Given values $\alpha_0, \alpha_1, \alpha_2 \in \mathbb{R}$, we say that the $\ell_1$-error of the quadratic function $H = \alpha_2 A^2 + \alpha_1 A + \alpha_0$ is equal to
# $$
# \displaystyle \sum_{i=1}^{15} |\text{obs_ht}_{~i} - (\alpha_2 \times \text{obs_age}_{~i}^2 + \alpha_1 \times \text{obs_age}_{~i} + \alpha_0)|.
# $$
#
# <font color="blue"><b>Your second task:</b></font>
# Write an LP that finds parameters $\alpha_0$, $\alpha_1$ and $\alpha_2$ so that the quadratic function $H = \alpha_2 A^2 + \alpha_1 A + \alpha_0$ minimizes the $\ell_1$-error.<br>
# Implement this LP and solve it. Also, plot the optimal curve $H$ that you found together with the data.

# %%
# Solve the L-1 quadratic regression problem here...

from pulp import *


Re_LP = LpProblem("regression", LpMinimize)

alpha_2 = LpVariable("alpha_2")
alpha_1 = LpVariable("alpha_1")
alpha_0 = LpVariable("alpha_0")
z = [LpVariable(f"abs{i}", lowBound=0) for i in range(15)]

Re_LP += lpSum(z)

for i in range(15):
    Re_LP += z[i] >= obs_ht[i] - (alpha_2 * obs_age[i] ** 2 + alpha_1 * obs_age[i] + alpha_0)
    Re_LP += z[i] >= -obs_ht[i] + (alpha_2 * obs_age[i] ** 2 + alpha_1 * obs_age[i] + alpha_0)

print(Re_LP)

Re_LP.solve()

print(f'The optimal alpha_2 is {alpha_2.value()}')
print(f'The optimal alpha_1 is {alpha_1.value()}')
print(f'The optimal alpha_0 is {alpha_0.value()}')


# Plot the points
plt.scatter(obs_age,obs_ht)

A = np.linspace(1,10,100)
H = alpha_2.value() * A * A + alpha_1.value() * A + alpha_0.value()
plt.plot(A, H, color='green')


plt.xlabel("Age (in years)")
plt.ylabel("Height (in cm)")
plt.show()
# Out:
# regression:
# MINIMIZE
# 1*abs0 + 1*abs1 + 1*abs10 + 1*abs11 + 1*abs12 + 1*abs13 + 1*abs14 + 1*abs2 + 1*abs3 + 1*abs4 + 1*abs5 + 1*abs6 + 1*abs7 + 1*abs8 + 1*abs9 + 0
# SUBJECT TO
# _C1: abs0 + alpha_0 + alpha_1 + alpha_2 >= 73.2
#
# _C2: abs0 - alpha_0 - alpha_1 - alpha_2 >= -73.2
#
# _C3: abs1 + alpha_0 + alpha_1 + alpha_2 >= 73.3
#
# _C4: abs1 - alpha_0 - alpha_1 - alpha_2 >= -73.3
#
# _C5: abs2 + alpha_0 + 2 alpha_1 + 4 alpha_2 >= 75.1
#
# _C6: abs2 - alpha_0 - 2 alpha_1 - 4 alpha_2 >= -75.1
#
# _C7: abs3 + alpha_0 + 2 alpha_1 + 4 alpha_2 >= 77.4
#
# _C8: abs3 - alpha_0 - 2 alpha_1 - 4 alpha_2 >= -77.4
#
# _C9: abs4 + alpha_0 + 3 alpha_1 + 9 alpha_2 >= 80.1
#
# _C10: abs4 - alpha_0 - 3 alpha_1 - 9 alpha_2 >= -80.1
#
# _C11: abs5 + alpha_0 + 4 alpha_1 + 16 alpha_2 >= 85.7
#
# _C12: abs5 - alpha_0 - 4 alpha_1 - 16 alpha_2 >= -85.7
#
# _C13: abs6 + alpha_0 + 4 alpha_1 + 16 alpha_2 >= 84
#
# _C14: abs6 - alpha_0 - 4 alpha_1 - 16 alpha_2 >= -84
#
# _C15: abs7 + alpha_0 + 5 alpha_1 + 25 alpha_2 >= 89.1
#
# _C16: abs7 - alpha_0 - 5 alpha_1 - 25 alpha_2 >= -89.1
#
# _C17: abs8 + alpha_0 + 6 alpha_1 + 36 alpha_2 >= 100.2
#
# _C18: abs8 - alpha_0 - 6 alpha_1 - 36 alpha_2 >= -100.2
#
# _C19: abs9 + alpha_0 + 7 alpha_1 + 49 alpha_2 >= 105.3
#
# _C20: abs9 - alpha_0 - 7 alpha_1 - 49 alpha_2 >= -105.3
#
# _C21: abs10 + alpha_0 + 7 alpha_1 + 49 alpha_2 >= 112.2
#
# _C22: abs10 - alpha_0 - 7 alpha_1 - 49 alpha_2 >= -112.2
#
# _C23: abs11 + alpha_0 + 8 alpha_1 + 64 alpha_2 >= 115
#
# _C24: abs11 - alpha_0 - 8 alpha_1 - 64 alpha_2 >= -115
#
# _C25: abs12 + alpha_0 + 9 alpha_1 + 81 alpha_2 >= 125.1
#
# _C26: abs12 - alpha_0 - 9 alpha_1 - 81 alpha_2 >= -125.1
#
# _C27: abs13 + alpha_0 + 9 alpha_1 + 81 alpha_2 >= 135.2
#
# _C28: abs13 - alpha_0 - 9 alpha_1 - 81 alpha_2 >= -135.2
#
# _C29: abs14 + alpha_0 + 10 alpha_1 + 100 alpha_2 >= 150.7
#
# _C30: abs14 - alpha_0 - 10 alpha_1 - 100 alpha_2 >= -150.7
#
# VARIABLES
# abs0 Continuous
# abs1 Continuous
# abs10 Continuous
# abs11 Continuous
# abs12 Continuous
# abs13 Continuous
# abs14 Continuous
# abs2 Continuous
# abs3 Continuous
# abs4 Continuous
# abs5 Continuous
# abs6 Continuous
# abs7 Continuous
# abs8 Continuous
# abs9 Continuous
# alpha_0 free Continuous
# alpha_1 free Continuous
# alpha_2 free Continuous
#
# The optimal alpha_2 is 0.83416667
# The optimal alpha_1 is -0.60416667
# The optimal alpha_0 is 73.07
